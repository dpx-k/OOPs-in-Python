# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import folium 

inty = 6 
listy = [5,10]

stringy = "Hello"

azores = folium.folium.Map(location =(38, -27), zoom_start = 6).save('output.html')
print(azores)
# Out:
# None

# %%
# get the path of the imported module
folium.__file__
# Out:
# '/Users/deepak/Desktop/OOPS with Python/.venv/lib/python3.13/site-packages/folium/__init__.py'
